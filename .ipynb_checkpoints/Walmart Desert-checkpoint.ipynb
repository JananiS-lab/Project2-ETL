# %% [markdown]
# # Walmart Deserts in USA - Poverty Rate Vs. Walmart Locations
# ---
# The below script explores the relationship between states with high poverty rates and the number of Walmart stores in those states.
#
# In this script, we:
# 1. Extracted Walmart store locations from DataWorld.com
# 2. Retrieved data from the 2018 US Census API and Google API to show the relationship between various socioeconomic parameters and Walmart Store counts across selected zip codes.
# 3. Transformed the data using Pandas, Numpy, Matplotlib, o accomplish our task.
# 4. Plotted the data in heatmaps using Requests, Census API, and Google API.
# 5. Stored the final data into PostgreSQL using SQLAlchemy

# %% [markdown]
# ## Extract Data: From csv file into a Pandas DataFrame

# %%
# Dependencies
import pandas as pd

# Read the Walmart Store Locations from the CSV file (from DataWorld)
input_file_path = "walmartstorelocation.csv"
walmart_locations_df = pd.read_csv(input_file_path)

walmart_locations_df
# Output: 4654 rows × 22 columns
# Out:
#                               name  \
# 0               Conway Supercenter
# 1             Sikeston Supercenter
# 2            Tahlequah Supercenter
# 3        Mountain Home Supercenter
# 4            Claremore Supercenter
# ...                            ...
# 4649  Pearland Neighborhood Market
# 4650       Bentonville Gas Station
# 4651         Millcreek Pickup only
# 4652            Dallas Supercenter
# 4653            Murray Pickup only
#
#                                                     url  \
# 0     https://www.walmart.com/store/5/conway-ar/details
# 1     https://www.walmart.com/store/9/sikeston-mo/de...
# 2     https://www.walmart.com/store/10/tahlequah-ok/...
# 3     https://www.walmart.com/store/11/mountain-home...
# 4     https://www.walmart.com/store/12/claremore-ok/...
# ...                                                 ...
# 4649  https://www.walmart.com/store/7361/pearland-tx...
# 4650  https://www.walmart.com/store/7368/bentonville...
# 4651  https://www.walmart.com/store/8855/millcreek-u...
# 4652  https://www.walmart.com/store/8930/dallas-tx/d...
# 4653  https://www.walmart.com/store/8862/murray-ut/d...
#
#               street_address           city state  zip_code country  \
# 0          1155 Hwy 65 North         Conway    AR     72032      US
# 1             1303 S Main St       Sikeston    MO     63801      US
# 2        2020 S Muskogee Ave      Tahlequah    OK     74464      US
# 3             65 Wal Mart Dr  Mountain Home    AR     72653      US
# 4     1500 S Lynn Riggs Blvd      Claremore    OK     74017      US
# ...                      ...            ...   ...       ...     ...
# 4649   12631 Broadway Street       Pearland    TX     77584      US
# 4650      1300 S Walton Blvd    Bentonville    AR     72712      US
# 4651      3701 S Highland Dr      Millcreek    UT     84106      US
# 4652           15757 Coit Rd         Dallas    TX     75248      US
# 4653  5596 S Van Winkle Expy         Murray    UT     84117      US
#
#      phone_number_1  phone_number_2  fax_1  ...  email_2  website  \
# 0      501-329-0023             NaN    NaN  ...      NaN      NaN
# 1      573-472-3020             NaN    NaN  ...      NaN      NaN
# 2      918-456-8804             NaN    NaN  ...      NaN      NaN
# 3      870-492-9299             NaN    NaN  ...      NaN      NaN
# 4      918-341-2765             NaN    NaN  ...      NaN      NaN
# ...             ...             ...    ...  ...      ...      ...
# 4649   713-570-7925             NaN    NaN  ...      NaN      NaN
# 4650   479-271-2209             NaN    NaN  ...      NaN      NaN
# 4651   801-467-2882             NaN    NaN  ...      NaN      NaN
# 4652   972-235-0681             NaN    NaN  ...      NaN      NaN
# 4653   801-278-8290             NaN    NaN  ...      NaN      NaN
#
#                                              open_hours   latitude  \
# 0     monday - friday : 00:00-24:00, saturday : 00:0...  35.108660
# 1     monday - friday : 00:00-24:00, saturday : 00:0...  36.857394
# 2     monday - friday : 00:00-24:00, saturday : 00:0...  35.888765
# 3     monday - friday : 00:00-24:00, saturday : 00:0...  36.354957
# 4     monday - friday : 00:00-24:00, saturday : 00:0...  36.293955
# ...                                                 ...        ...
# 4649  monday - friday : 06:00-23:00, saturday : 06:0...  29.556350
# 4650  monday - friday : 00:00-24:00, saturday : 00:0...  36.357486
# 4651  monday - friday : 08:00-20:00, saturday : 08:0...  40.691031
# 4652  monday - friday : 00:00-24:00, saturday : 00:0...  32.963412
# 4653  monday - friday : 08:00-20:00, saturday : 08:0...  40.649827
#
#        longitude  facebook  twitter  instagram  pinterest  youtube
# 0     -92.436905       NaN      NaN        NaN        NaN      NaN
# 1     -89.586051       NaN      NaN        NaN        NaN      NaN
# 2     -94.979859       NaN      NaN        NaN        NaN      NaN
# 3     -92.341026       NaN      NaN        NaN        NaN      NaN
# 4     -95.627125       NaN      NaN        NaN        NaN      NaN
# ...          ...       ...      ...        ...        ...      ...
# 4649  -95.415782       NaN      NaN        NaN        NaN      NaN
# 4650  -94.214669       NaN      NaN        NaN        NaN      NaN
# 4651 -111.846529       NaN      NaN        NaN        NaN      NaN
# 4652  -96.770294       NaN      NaN        NaN        NaN      NaN
# 4653 -111.849349       NaN      NaN        NaN        NaN      NaN
#
# [4654 rows x 22 columns]

# %%
# Filtering on columns of interest
walmart_locations_clean_df = walmart_locations_df.filter(["name", "latitude", "latitude","city", "state","zip_code"])
walmart_locations_clean_df
# Out:
#                               name   latitude   latitude           city state  \
# 0               Conway Supercenter  35.108660  35.108660         Conway    AR
# 1             Sikeston Supercenter  36.857394  36.857394       Sikeston    MO
# 2            Tahlequah Supercenter  35.888765  35.888765      Tahlequah    OK
# 3        Mountain Home Supercenter  36.354957  36.354957  Mountain Home    AR
# 4            Claremore Supercenter  36.293955  36.293955      Claremore    OK
# ...                            ...        ...        ...            ...   ...
# 4649  Pearland Neighborhood Market  29.556350  29.556350       Pearland    TX
# 4650       Bentonville Gas Station  36.357486  36.357486    Bentonville    AR
# 4651         Millcreek Pickup only  40.691031  40.691031      Millcreek    UT
# 4652            Dallas Supercenter  32.963412  32.963412         Dallas    TX
# 4653            Murray Pickup only  40.649827  40.649827         Murray    UT
#
#       zip_code
# 0        72032
# 1        63801
# 2        74464
# 3        72653
# 4        74017
# ...        ...
# 4649     77584
# 4650     72712
# 4651     84106
# 4652     75248
# 4653     84117
#
# [4654 rows x 6 columns]

# %%
# Drop na values
walmart_locations_clean_df.dropna(how='any')
walmart_locations_clean_df
# Out:
#                               name   latitude   latitude           city state  \
# 0               Conway Supercenter  35.108660  35.108660         Conway    AR
# 1             Sikeston Supercenter  36.857394  36.857394       Sikeston    MO
# 2            Tahlequah Supercenter  35.888765  35.888765      Tahlequah    OK
# 3        Mountain Home Supercenter  36.354957  36.354957  Mountain Home    AR
# 4            Claremore Supercenter  36.293955  36.293955      Claremore    OK
# ...                            ...        ...        ...            ...   ...
# 4649  Pearland Neighborhood Market  29.556350  29.556350       Pearland    TX
# 4650       Bentonville Gas Station  36.357486  36.357486    Bentonville    AR
# 4651         Millcreek Pickup only  40.691031  40.691031      Millcreek    UT
# 4652            Dallas Supercenter  32.963412  32.963412         Dallas    TX
# 4653            Murray Pickup only  40.649827  40.649827         Murray    UT
#
#       zip_code
# 0        72032
# 1        63801
# 2        74464
# 3        72653
# 4        74017
# ...        ...
# 4649     77584
# 4650     72712
# 4651     84106
# 4652     75248
# 4653     84117
#
# [4654 rows x 6 columns]

# %%
# Check the datatype of the Zipcode column
walmart_locations_df.dtypes
# Out:
# name               object
# url                object
# street_address     object
# city               object
# state              object
# zip_code            int64
# country            object
# phone_number_1     object
# phone_number_2    float64
# fax_1             float64
# fax_2             float64
# email_1           float64
# email_2           float64
# website           float64
# open_hours         object
# latitude          float64
# longitude         float64
# facebook          float64
# twitter           float64
# instagram         float64
# pinterest         float64
# youtube           float64
# dtype: object

# %% [markdown]
# # Extract Data: From US zipcde data from csv file into a Pandas DataFrame

# %%
# Read the US zipcode lat long info from the CSV file (from OpenDataSoft.com)
zip_file_path = "us-zip-code-latitude-and-longitude.csv"
us_zipcode_latlng_df = pd.read_csv(zip_file_path, delimiter =";")

us_zipcode_latlng_df

# Output:  43191 rows × 8 columns
# Out:
#          Zip          City State   Latitude  Longitude  Timezone  \
# 0      71937          Cove    AR  34.398483 -94.393980        -6
# 1      72044      Edgemont    AR  35.624351 -92.160560        -6
# 2      56171      Sherburn    MN  43.660847 -94.743570        -6
# 3      49430        Lamont    MI  43.010337 -85.897540        -5
# 4      52585      Richland    IA  41.194129 -91.980270        -6
# ...      ...           ...   ...        ...        ...       ...
# 43186  15207    Pittsburgh    PA  40.399355 -79.934140        -5
# 43187  52647          Olds    IA  41.133346 -91.545590        -6
# 43188  16683  Spruce Creek    PA  40.662087 -78.070120        -5
# 43189  55459   Minneapolis    MN  45.015914 -93.471880        -6
# 43190  21123      Pasadena    MD  38.974203 -76.594942        -5
#
#        Daylight savings time flag              geopoint
# 0                               1   34.398483,-94.39398
# 1                               1   35.624351,-92.16056
# 2                               1   43.660847,-94.74357
# 3                               1   43.010337,-85.89754
# 4                               1   41.194129,-91.98027
# ...                           ...                   ...
# 43186                           1   40.399355,-79.93414
# 43187                           1   41.133346,-91.54559
# 43188                           1   40.662087,-78.07012
# 43189                           1   45.015914,-93.47188
# 43190                           1  38.974203,-76.594942
#
# [43191 rows x 8 columns]

# %%
us_zipcode_latlng_df = us_zipcode_latlng_df.dropna(how='any')
us_zipcode_latlng_df
# Out:
#          Zip          City State   Latitude  Longitude  Timezone  \
# 0      71937          Cove    AR  34.398483 -94.393980        -6
# 1      72044      Edgemont    AR  35.624351 -92.160560        -6
# 2      56171      Sherburn    MN  43.660847 -94.743570        -6
# 3      49430        Lamont    MI  43.010337 -85.897540        -5
# 4      52585      Richland    IA  41.194129 -91.980270        -6
# ...      ...           ...   ...        ...        ...       ...
# 43186  15207    Pittsburgh    PA  40.399355 -79.934140        -5
# 43187  52647          Olds    IA  41.133346 -91.545590        -6
# 43188  16683  Spruce Creek    PA  40.662087 -78.070120        -5
# 43189  55459   Minneapolis    MN  45.015914 -93.471880        -6
# 43190  21123      Pasadena    MD  38.974203 -76.594942        -5
#
#        Daylight savings time flag              geopoint
# 0                               1   34.398483,-94.39398
# 1                               1   35.624351,-92.16056
# 2                               1   43.660847,-94.74357
# 3                               1   43.010337,-85.89754
# 4                               1   41.194129,-91.98027
# ...                           ...                   ...
# 43186                           1   40.399355,-79.93414
# 43187                           1   41.133346,-91.54559
# 43188                           1   40.662087,-78.07012
# 43189                           1   45.015914,-93.47188
# 43190                           1  38.974203,-76.594942
#
# [43191 rows x 8 columns]

# %%
# Renaming columns of interest - lat, long, zipcode
us_zipcode_df = us_zipcode_latlng_df.rename(columns=({"Zip":"zipcode", 
                                                            "Latitude": "latitude",
                                                            "Longitude": "longitude"}))
us_zipcode_df
# Out:
#        zipcode          City State   latitude  longitude  Timezone  \
# 0        71937          Cove    AR  34.398483 -94.393980        -6
# 1        72044      Edgemont    AR  35.624351 -92.160560        -6
# 2        56171      Sherburn    MN  43.660847 -94.743570        -6
# 3        49430        Lamont    MI  43.010337 -85.897540        -5
# 4        52585      Richland    IA  41.194129 -91.980270        -6
# ...        ...           ...   ...        ...        ...       ...
# 43186    15207    Pittsburgh    PA  40.399355 -79.934140        -5
# 43187    52647          Olds    IA  41.133346 -91.545590        -6
# 43188    16683  Spruce Creek    PA  40.662087 -78.070120        -5
# 43189    55459   Minneapolis    MN  45.015914 -93.471880        -6
# 43190    21123      Pasadena    MD  38.974203 -76.594942        -5
#
#        Daylight savings time flag              geopoint
# 0                               1   34.398483,-94.39398
# 1                               1   35.624351,-92.16056
# 2                               1   43.660847,-94.74357
# 3                               1   43.010337,-85.89754
# 4                               1   41.194129,-91.98027
# ...                           ...                   ...
# 43186                           1   40.399355,-79.93414
# 43187                           1   41.133346,-91.54559
# 43188                           1   40.662087,-78.07012
# 43189                           1   45.015914,-93.47188
# 43190                           1  38.974203,-76.594942
#
# [43191 rows x 8 columns]

# %%
us_zipcode_latlng_df = us_zipcode_df.filter(['zipcode', 'latitude','longitude'])
us_zipcode_latlng_df
# Out:
#        zipcode   latitude  longitude
# 0        71937  34.398483 -94.393980
# 1        72044  35.624351 -92.160560
# 2        56171  43.660847 -94.743570
# 3        49430  43.010337 -85.897540
# 4        52585  41.194129 -91.980270
# ...        ...        ...        ...
# 43186    15207  40.399355 -79.934140
# 43187    52647  41.133346 -91.545590
# 43188    16683  40.662087 -78.070120
# 43189    55459  45.015914 -93.471880
# 43190    21123  38.974203 -76.594942
#
# [43191 rows x 3 columns]

# %%
us_zipcode_latlng_df = us_zipcode_latlng_df.dropna(how='any')
us_zipcode_latlng_df
# Out:
#        zipcode   latitude  longitude
# 0        71937  34.398483 -94.393980
# 1        72044  35.624351 -92.160560
# 2        56171  43.660847 -94.743570
# 3        49430  43.010337 -85.897540
# 4        52585  41.194129 -91.980270
# ...        ...        ...        ...
# 43186    15207  40.399355 -79.934140
# 43187    52647  41.133346 -91.545590
# 43188    16683  40.662087 -78.070120
# 43189    55459  45.015914 -93.471880
# 43190    21123  38.974203 -76.594942
#
# [43191 rows x 3 columns]

# %%
# Check dtypes
us_zipcode_latlng_df.dtypes
# Out:
# zipcode        int64
# latitude     float64
# longitude    float64
# dtype: object

# %% [markdown]
# ## Transform store data to get teh store counts per zipcode

# %%
# Select required columns in a new dataframe
stores_df = walmart_locations_df[["name", "zip_code"]]
stores_df
# Output: 4654 rows × 2 columns
# Out:
#                               name  zip_code
# 0               Conway Supercenter     72032
# 1             Sikeston Supercenter     63801
# 2            Tahlequah Supercenter     74464
# 3        Mountain Home Supercenter     72653
# 4            Claremore Supercenter     74017
# ...                            ...       ...
# 4649  Pearland Neighborhood Market     77584
# 4650       Bentonville Gas Station     72712
# 4651         Millcreek Pickup only     84106
# 4652            Dallas Supercenter     75248
# 4653            Murray Pickup only     84117
#
# [4654 rows x 2 columns]

# %%
# Group by zipcode to find the count of stores per zipcode and store this grouped data in a new dataframe
store_count_df = stores_df.groupby(["zip_code"]).count()
store_count_df
# Output: 4177 rows × 1 columns
# Out:
#           name
# zip_code
# 617          1
# 659          1
# 662          1
# 674          1
# 680          1
# ...        ...
# 99611        1
# 99615        1
# 99654        1
# 99701        1
# 99901        1
#
# [4177 rows x 1 columns]

# %%
# Rename the Name column to "Store Count" column 
store_count_df = store_count_df.rename(columns={'name': "count"})
store_count_df
# Out:
#           count
# zip_code
# 617           1
# 659           1
# 662           1
# 674           1
# 680           1
# ...         ...
# 99611         1
# 99615         1
# 99654         1
# 99701         1
# 99901         1
#
# [4177 rows x 1 columns]

# %%
# Reset the Index and store in a new dataframe
store_count_clean_df = store_count_df.reset_index()
store_count_clean_df
# Out:
#       zip_code  count
# 0          617      1
# 1          659      1
# 2          662      1
# 3          674      1
# 4          680      1
# ...        ...    ...
# 4172     99611      1
# 4173     99615      1
# 4174     99654      1
# 4175     99701      1
# 4176     99901      1
#
# [4177 rows x 2 columns]

# %%
# Rename columns to match database schema
store_count_clean_df = store_count_clean_df.rename(columns={'zip_code': "zipcode",
                                                           'count': "store_count"})
store_count_clean_df
# Out:
#       zipcode  store_count
# 0         617            1
# 1         659            1
# 2         662            1
# 3         674            1
# 4         680            1
# ...       ...          ...
# 4172    99611            1
# 4173    99615            1
# 4174    99654            1
# 4175    99701            1
# 4176    99901            1
#
# [4177 rows x 2 columns]

# %% [markdown]
# ## Run Census Search to retrieve data on all zip codes (2018 ACS5 Census)
# ##### See: https://github.com/CommerceDataService/census-wrapper for library documentation
# ##### See: https://gist.github.com/afhaque/60558290d6efd892351c4b64e5c01e9b for labels

# %%
# Census Dependencies
# Census API Key
from config import (census_key, gkey)
from census import Census
c = Census(census_key, year=2018)

census_data = c.acs5.get(("B01003_001E", "B17001_002E"), {'for': 'zip code tabulation area:*'})

# Convert to DataFrame
census_df = pd.DataFrame(census_data)

# Column Reordering
census_df = census_df.rename(columns={"B01003_001E": "population",
                                      "B17001_002E": "poverty_count",
                                      "zip code tabulation area": "zipcode"})

# Add in Poverty Rate (Poverty Count / Population)
census_df["poverty_rate"] = (census_df["poverty_count"]/census_df["population"])*100
row_count = len(census_df)

print(f"Total number of records: {row_count}")
census_df

# Output: 33120 rows × 4 columns
# Out:
# Total number of records: 33120
#        population  poverty_count zipcode  poverty_rate
# 0         17242.0        10772.0   00601     62.475351
# 1         38442.0        19611.0   00602     51.014515
# 2         48814.0        24337.0   00603     49.856599
# 3          6437.0         4163.0   00606     64.672984
# 4         27073.0        11724.0   00610     43.305138
# ...           ...            ...     ...           ...
# 33115        15.0            0.0   99923      0.000000
# 33116       927.0          172.0   99925     18.554477
# 33117      1635.0          235.0   99926     14.373089
# 33118        38.0           28.0   99927     73.684211
# 33119      2484.0          192.0   99929      7.729469
#
# [33120 rows x 4 columns]

# %%
census_df.dtypes
# Out:
# population       float64
# poverty_count    float64
# zipcode           object
# poverty_rate     float64
# dtype: object

# %%
census_df["zipcode"] = census_df["zipcode"].astype(int)
census_df.dtypes
# Out:
# population       float64
# poverty_count    float64
# zipcode            int32
# poverty_rate     float64
# dtype: object

# %% [markdown]
# ## Transform Data: Merge the store counts with poverty data per zipcode

# %%
# Merge the two data sets along zip code
stores_per_zip_df = pd.merge(store_count_clean_df, census_df, how="left", on=["zipcode"])

# Remove rows missing data
stores_per_zip_clean_df = stores_per_zip_df.dropna()

# Visualize
stores_per_zip_clean_df

#Output: 4168 rows × 5 columns
# Out:
#       zipcode  store_count  population  poverty_count  poverty_rate
# 0         617            1     23974.0        11879.0     49.549512
# 1         659            1     40390.0        18717.0     46.340678
# 2         662            1     40290.0        21809.0     54.130057
# 3         674            1     39859.0        18226.0     45.726185
# 4         680            1     46395.0        23841.0     51.387003
# ...       ...          ...         ...            ...           ...
# 4172    99611            1     15657.0         2041.0     13.035703
# 4173    99615            1     12971.0         1100.0      8.480456
# 4174    99654            1     62135.0         6236.0     10.036211
# 4175    99701            1     17510.0         2359.0     13.472302
# 4176    99901            1     13818.0         1441.0     10.428427
#
# [4168 rows x 5 columns]

# %%
stores_per_zip_clean_df.dtypes
# Out:
# zipcode            int64
# store_count        int64
# population       float64
# poverty_count    float64
# poverty_rate     float64
# dtype: object

# %%
# Merge the two data sets along zip code to get the Lat Long
merged_df = pd.merge(stores_per_zip_clean_df, us_zipcode_latlng_df, how="left", on=["zipcode"])

merged_df
# Out:
#       zipcode  store_count  population  poverty_count  poverty_rate  \
# 0         617            1     23974.0        11879.0     49.549512
# 1         659            1     40390.0        18717.0     46.340678
# 2         662            1     40290.0        21809.0     54.130057
# 3         674            1     39859.0        18226.0     45.726185
# 4         680            1     46395.0        23841.0     51.387003
# ...       ...          ...         ...            ...           ...
# 4163    99611            1     15657.0         2041.0     13.035703
# 4164    99615            1     12971.0         1100.0      8.480456
# 4165    99654            1     62135.0         6236.0     10.036211
# 4166    99701            1     17510.0         2359.0     13.472302
# 4167    99901            1     13818.0         1441.0     10.428427
#
#        latitude  longitude
# 0     18.455499  -66.55575
# 1     18.432956  -66.80039
# 2     18.478855  -67.01973
# 3     18.426137  -66.48697
# 4     18.205232  -67.12655
# ...         ...        ...
# 4163  60.587598 -151.23355
# 4164  57.746630 -152.51142
# 4165  61.580187 -149.48821
# 4166  64.835070 -147.72045
# 4167  55.368644 -131.67620
#
# [4168 rows x 7 columns]

# %%
merged_df = merged_df.dropna(how='any')
merged_df
# Out:
#       zipcode  store_count  population  poverty_count  poverty_rate  \
# 0         617            1     23974.0        11879.0     49.549512
# 1         659            1     40390.0        18717.0     46.340678
# 2         662            1     40290.0        21809.0     54.130057
# 3         674            1     39859.0        18226.0     45.726185
# 4         680            1     46395.0        23841.0     51.387003
# ...       ...          ...         ...            ...           ...
# 4163    99611            1     15657.0         2041.0     13.035703
# 4164    99615            1     12971.0         1100.0      8.480456
# 4165    99654            1     62135.0         6236.0     10.036211
# 4166    99701            1     17510.0         2359.0     13.472302
# 4167    99901            1     13818.0         1441.0     10.428427
#
#        latitude  longitude
# 0     18.455499  -66.55575
# 1     18.432956  -66.80039
# 2     18.478855  -67.01973
# 3     18.426137  -66.48697
# 4     18.205232  -67.12655
# ...         ...        ...
# 4163  60.587598 -151.23355
# 4164  57.746630 -152.51142
# 4165  61.580187 -149.48821
# 4166  64.835070 -147.72045
# 4167  55.368644 -131.67620
#
# [4123 rows x 7 columns]

# %%
merged_df.dtypes
# Out:
# zipcode            int64
# store_count        int64
# population       float64
# poverty_count    float64
# poverty_rate     float64
# latitude         float64
# longitude        float64
# dtype: object

# %% [markdown]
# # # Loading Data into a PostgreSQL Database

# %%
# Dependencies
from sqlalchemy import create_engine
from config import (postgres_id, postgres_pw)

# %%
# Connect to a local database
conn_str = f"{postgres_id}:{postgres_pw}@localhost:5432/etl_project_db"
engine = create_engine(f'postgresql://{conn_str}')

# %%
# check tables in the database
engine.table_names()
# Out:
# ['store_counts', 'walmart_stores', 'final_df']

# %%
# Load the DataFrames into the database
store_count_clean_df.to_sql(name='store_counts', con=engine, if_exists='append', index=False)

# %%
# Confirm that the data loaded correctly
pd.read_sql_query('select * from store_counts', con=engine)
# Out:
#       zipcode  store_count
# 0         617            1
# 1         659            1
# 2         662            1
# 3         674            1
# 4         680            1
# ...       ...          ...
# 4172    99611            1
# 4173    99615            1
# 4174    99654            1
# 4175    99701            1
# 4176    99901            1
#
# [4177 rows x 2 columns]

# %%
# Load the merged DataFrames into the database
stores_per_zip_clean_df.to_sql(name='walmart_stores', con=engine, if_exists='append', index=False)

# %%
# Confirm that the data loaded correctly
pd.read_sql_query('select * from walmart_stores', con=engine)
# Out:
#       zipcode  store_count  population  poverty_count  poverty_rate
# 0         617            1     23974.0        11879.0     49.549512
# 1         659            1     40390.0        18717.0     46.340678
# 2         662            1     40290.0        21809.0     54.130057
# 3         674            1     39859.0        18226.0     45.726185
# 4         680            1     46395.0        23841.0     51.387003
# ...       ...          ...         ...            ...           ...
# 4163    99611            1     15657.0         2041.0     13.035703
# 4164    99615            1     12971.0         1100.0      8.480456
# 4165    99654            1     62135.0         6236.0     10.036211
# 4166    99701            1     17510.0         2359.0     13.472302
# 4167    99901            1     13818.0         1441.0     10.428427
#
# [4168 rows x 5 columns]

# %%
# Load the final DataFrame into the database
merged_df.to_sql(name='final_df', con=engine, if_exists='append', index=False)

# %%
# Confirm that the data loaded correctly
pd.read_sql_query('select * from final_df', con=engine)
# Out:
#       zipcode  store_count  population  poverty_count  poverty_rate  \
# 0         617            1     23974.0        11879.0     49.549512
# 1         659            1     40390.0        18717.0     46.340678
# 2         662            1     40290.0        21809.0     54.130057
# 3         674            1     39859.0        18226.0     45.726185
# 4         680            1     46395.0        23841.0     51.387003
# ...       ...          ...         ...            ...           ...
# 4118    99611            1     15657.0         2041.0     13.035703
# 4119    99615            1     12971.0         1100.0      8.480456
# 4120    99654            1     62135.0         6236.0     10.036211
# 4121    99701            1     17510.0         2359.0     13.472302
# 4122    99901            1     13818.0         1441.0     10.428427
#
#        latitude  longitude
# 0     18.455499  -66.55575
# 1     18.432956  -66.80039
# 2     18.478855  -67.01973
# 3     18.426137  -66.48697
# 4     18.205232  -67.12655
# ...         ...        ...
# 4118  60.587598 -151.23355
# 4119  57.746630 -152.51142
# 4120  61.580187 -149.48821
# 4121  64.835070 -147.72045
# 4122  55.368644 -131.67620
#
# [4123 rows x 7 columns]

# %% [markdown]
# ## Heatmap of Poverty Rate

# %%
import gmaps
import numpy as np
import pandas as pd
import requests
import time
from scipy.stats import linregress
from matplotlib import pyplot as plt

# %%
# Configure gmaps with API key
gmaps.configure(api_key=gkey)

# %%
# Store the Walmart store location (Latitude and 'Longitude) into  a series "locations" for plotting
locations = merged_df[["latitude", "longitude"]].astype(float)

# %%
locations
# Out:
#        latitude  longitude
# 0     18.455499  -66.55575
# 1     18.432956  -66.80039
# 2     18.478855  -67.01973
# 3     18.426137  -66.48697
# 4     18.205232  -67.12655
# ...         ...        ...
# 4163  60.587598 -151.23355
# 4164  57.746630 -152.51142
# 4165  61.580187 -149.48821
# 4166  64.835070 -147.72045
# 4167  55.368644 -131.67620
#
# [4123 rows x 2 columns]

# %%
# Create a map
fig = gmaps.figure()
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# #### Add a Symbol layer for store counts

# %%
# Convert store count to a list
store_count = merged_df["store_count"].tolist()

# %%
# Add the Store symbol layer
store_layer = gmaps.symbol_layer(locations, fill_color='rgba(0, 150, 0, 0.4)',
    stroke_color='rgba(0, 0, 150, 0.4)', scale=2,
    info_box_content=[f"Store Count: {store}" for store in store_count]
)


fig = gmaps.figure()
fig.add_layer(store_layer)

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# #### Add a Heatmap layer with  poverty rate

# %%
#Create a list of poverty rate as a float
poverty_rate = merged_df["poverty_rate"].tolist()
poverty_rate
# Out:
# [49.549511971302245,
#  46.34067838573904,
#  54.130057086125596,
#  45.72618480142502,
#  51.38700290979631,
#  41.22649121718081,
#  46.35246108116278,
#  42.569728451534125,
#  43.78941595832191,
#  43.00105346326047,
#  47.09507840116016,
#  38.86552819016562,
#  49.06476588423252,
#  44.015730198274625,
#  26.459696333785953,
#  33.73347227673194,
#  30.765982328482327,
#  26.253475804900226,
#  10.622321161577567,
#  5.630885122410547,
#  14.449584891311238,
#  14.632533534857359,
#  6.690191216441753,
#  19.873770732423306,
#  13.865536799157082,
#  15.160855326526681,
#  10.31470777135517,
#  14.089029433227926,
#  13.19175545347411,
#  6.5655221364563925,
#  7.867284844972472,
#  2.1221221221221223,
#  7.033639143730887,
#  5.1263794944820225,
#  4.9504950495049505,
#  5.565217391304348,
#  14.155889549108702,
#  4.000614062020264,
#  5.7932353533319905,
#  3.3827778848006163,
#  9.190507607109298,
#  2.8896560542130163,
#  17.80875711761241,
#  9.44079531333215,
#  5.521360673052409,
#  14.475727030471555,
#  3.408556652562295,
#  3.576220456187429,
#  11.778948112540649,
#  4.382808922613986,
#  17.348122487247533,
#  10.196340919232485,
#  4.33282208588957,
#  2.792248385080225,
#  3.717085119412125,
#  6.392369742783218,
#  5.962829117191534,
#  12.336414386382355,
#  7.375514788468738,
#  20.545911375057106,
#  6.205341953045253,
#  8.54269519107698,
#  4.781516124528828,
#  4.7666009204470745,
#  4.6387318751536,
#  7.844630616907845,
#  13.459135754599114,
#  9.831600925967955,
#  6.987968421415521,
#  5.979026451713883,
#  10.045055726820014,
#  3.690495936307846,
#  17.734748705851516,
#  3.374949657672171,
#  1.3429298692179408,
#  7.7189144445101405,
#  8.512790865732041,
#  4.994472520530638,
#  4.359317612329661,
#  17.486251693631942,
#  4.301908047595578,
#  1.7554046810791497,
#  7.894369149084812,
#  9.93567811687423,
#  4.792448263342611,
#  10.635074536419827,
#  11.294819934807368,
#  13.13666162380232,
#  5.339010809040288,
#  2.6847016020186607,
#  10.236937167562647,
#  7.933636873947483,
#  18.281482101387116,
#  17.455351556215028,
#  10.672517115978897,
#  14.314102355279019,
#  20.276953511374877,
#  7.63360739979445,
#  20.709694461565554,
#  17.539267015706805,
#  8.666412891765004,
#  18.127957374050656,
#  7.985946895480035,
#  6.996928177873128,
#  13.213526570048309,
#  28.46511627906977,
#  5.315107734462573,
#  18.288412231880432,
#  10.175212378640778,
#  20.819352321498243,
#  16.822757272961912,
#  4.273670054568495,
#  7.991032108255265,
#  22.45632481397606,
#  12.815457413249213,
#  17.514832242225857,
#  12.281576551185882,
#  4.232613368204296,
#  11.967287596547024,
#  20.130044602074264,
#  9.963313971262611,
#  9.457390196940525,
#  19.545510379560252,
#  5.477419647858538,
#  6.269356153219234,
#  6.383668178872326,
#  11.397011325954955,
#  8.742742295667709,
#  26.140630625996604,
#  12.672799085334166,
#  11.094167937404695,
#  23.34186219536538,
#  13.097602966494504,
#  6.919246739373891,
#  14.67666268052617,
#  15.291887793783168,
#  12.039090396542003,
#  5.293759883225885,
#  25.163738580463807,
#  7.5343344885123855,
#  16.07461413169937,
#  18.87965062568237,
#  16.133200344561818,
#  9.843093543685159,
#  8.982175268767161,
#  7.4347725698453,
#  18.58503401360544,
#  8.757245348790077,
#  18.441929650586246,
#  21.248301994709372,
#  13.746818486269257,
#  6.577385192572541,
#  5.501945525291829,
#  8.019043117128675,
#  23.87660195749743,
#  19.55416638043553,
#  21.234069500514526,
#  9.260363260601725,
#  0.0,
#  11.746049006814557,
#  15.29014791854671,
#  5.5491496108388585,
#  5.665106951871658,
#  21.071095142444904,
#  14.286348896095241,
#  23.187683948381256,
#  19.276601710360296,
#  8.020200086161505,
#  28.19275137036734,
#  15.145303267816232,
#  20.390751957453094,
#  20.390125907089253,
#  5.979963313108509,
#  16.706347979345104,
#  22.338408854644406,
#  16.96374182270837,
#  30.692767410659837,
#  16.00426947950022,
#  27.00397117223121,
#  33.38761841411107,
#  18.96189618961896,
#  23.480373957946608,
#  21.742193873766965,
#  13.462998102466795,
#  12.116055475197822,
#  4.7096843692771735,
#  16.960985626283367,
#  14.038205242114616,
#  15.059029296020988,
#  19.384359400998335,
#  ...]

# %%
# Add a heat layer with poverty_rate
poverty_heat_layer = gmaps.heatmap_layer(locations, weights=poverty_rate, dissipating=False, max_intensity=100, point_radius = 1)

fig = gmaps.figure()
fig.add_layer(poverty_heat_layer)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# ### Combine Poverty heat map with Store Count symbol layer

# %%
fig = gmaps.figure()
fig.add_layer(store_layer)
fig.add_layer(poverty_heat_layer)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# ### Statistical Analysis - Linear Regression to see relationship between Poverty Rate and Walmart store counts

# %%
## Convert to floats and store Poverty Rate and Bank Count as x and y values
x_values = merged_df['poverty_rate'].astype('float')
y_values = merged_df['store_count'].astype('float')

# Run linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot scatter plot
plt.scatter(x_values,y_values)

# Plot regression line
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")

# Label plot
plt.xlabel('Poverty Rate')
plt.ylabel('Store Count')

print(f"Correlation Coefficient: {rvalue}")

# Show plot
plt.show()
# Out:
# Correlation Coefficient: -0.030213719601892695

# %% [markdown]
# ## Conclusion
#        1. There is no correlation between poverty rates and the number of Walmart stores in the US.
